# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1234)  
PYTHONHASHSEED = 0
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score, classification_report
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

from datetime import datetime

import seaborn as sns

# %matplotlib inline

print(tf.__version__)
# Out:
# 2.9.1

# %%
# load training
train_df = pd.read_csv("./../data/PM_train.txt", sep=" ", header=None)

train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
train_df = train_df.sort_values(['id','cycle'])

# %%
# read test data - It is the aircraft engine operating data without failure events recorded.
test_df = pd.read_csv('./../data/PM_test.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %%
# read ground truth data - It contains the information of true remaining cycles for each engine in the testing data.
truth_df = pd.read_csv('./../data/PM_truth.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
#      # 1. TRAIN

# %%
# generate column RUL(Remaining Usefull Life or Time to Failure)
helpcols = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
helpcols.columns = ['id', 'max']
train_df = train_df.merge(helpcols, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)

# %%
# generate label columns for training data
# only make use of "label1" for binary classification, 
# while trying to answer the question: is a specific engine going to fail within w1 cycles?
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, 0 )
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2

# %%
# MinMax normalization (from 0 to 1)
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id','cycle','RUL','label1','label2'])
min_max = preprocessing.MinMaxScaler()
norm_train_df = pd.DataFrame(min_max.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

# %% [markdown]
#     # 2. TEST

# %%
# MinMax normalization (from 0 to 1)
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3   s1        s2        s3        s4  \
# 0   1      1  0.632184  0.750000       0.0  0.0  0.545181  0.310661  0.269413
# 1   1      2  0.344828  0.250000       0.0  0.0  0.150602  0.379551  0.222316
# 2   1      3  0.517241  0.583333       0.0  0.0  0.376506  0.346632  0.322248
# 3   1      4  0.741379  0.500000       0.0  0.0  0.370482  0.285154  0.408001
# 4   1      5  0.580460  0.500000       0.0  0.0  0.391566  0.352082  0.332039
#
#     s5  ...       s13       s14       s15  s16       s17  s18  s19       s20  \
# 0  0.0  ...  0.220588  0.132160  0.308965  0.0  0.333333  0.0  0.0  0.558140
# 1  0.0  ...  0.264706  0.204768  0.213159  0.0  0.416667  0.0  0.0  0.682171
# 2  0.0  ...  0.220588  0.155640  0.458638  0.0  0.416667  0.0  0.0  0.728682
# 3  0.0  ...  0.250000  0.170090  0.257022  0.0  0.250000  0.0  0.0  0.666667
# 4  0.0  ...  0.220588  0.152751  0.300885  0.0  0.166667  0.0  0.0  0.658915
#
#         s21  cycle_norm
# 0  0.661834     0.00000
# 1  0.686827     0.00277
# 2  0.721348     0.00554
# 3  0.662110     0.00831
# 4  0.716377     0.01108
#
# [5 rows x 27 columns]

# %%
# use the ground truth dataset to generate labels for the test data.
# generate column max for test data
helpcols = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
helpcols.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = helpcols['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# %%
# generate RUL for test data
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)

# generate label columns w0 and w1 for test data
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, 0 )
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2

# %%
# pick a large window size of 50 cycles
sequence_length = 50

# %%
# reshape features into (samples, time steps, features) 
def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # for one id I put all the rows in a single matrix
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    # Iterate over two lists in parallel.
    # For example id1 have 192 rows and sequence_length is equal to 50
    # so zip iterate over two following list of numbers (0,112),(50,192)
    # 0 50 -> from row 0 to row 50
    # 1 51 -> from row 1 to row 51
    # 2 52 -> from row 2 to row 52
    # ...
    # 111 191 -> from row 111 to 191
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]

# %%
# pick the feature columns 
sensor_cols = ['s' + str(i) for i in range(1,22)]
sequence_cols = ['setting1', 'setting2', 'setting3', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# %%
# val is a list of 192 - 50 = 142 bi-dimensional array (50 rows x 25 columns)
val=list(gen_sequence(train_df[train_df['id']==1], sequence_length, sequence_cols))
len(val)
# Out:
# 142

# %%
# generator for the sequences
# transform each id of the train dataset in a sequence
seq_gen = (list(gen_sequence(train_df[train_df['id']==id], sequence_length, sequence_cols)) 
           for id in train_df['id'].unique())

# %%
# concatenate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
seq_array.shape
# Out:
# (15631, 50, 25)

# %%
# generate labels
def gen_labels(id_df, seq_length, label):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # For one id I put all the labels in a single matrix.
    # For example:
    # [[1]
    # [4]
    # [1]
    # [5]
    # [9]
    # ...
    # [200]] 
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    # I have to remove the first seq_length labels
    # because for one id the first sequence of seq_length size have as target
    # the last label (the previus ones are discarded).
    # All the next id's sequences will have associated step by step one label as target.
    return data_matrix[seq_length:num_elements, :]

# %%
# generate labels
label_gen = [gen_labels(train_df[train_df['id']==id], sequence_length, ['RUL']) 
             for id in train_df['id'].unique()]

label_array = np.concatenate(label_gen).astype(np.float32)
label_array.shape
# Out:
# (15631, 1)

# %%
# TEST DATA

# We pick the last sequence for each id in the test data
seq_test_last = [test_df[test_df['id']==id][sequence_cols].values[-sequence_length:] 
                       for id in test_df['id'].unique() if len(test_df[test_df['id']==id]) >= sequence_length]

seq_test_last = np.asarray(seq_test_last).astype(np.float32)
print("seq_test_last")
print(seq_test_last.shape)

# Similarly, we pick the labels
y_mask = [len(test_df[test_df['id']==id]) >= sequence_length for id in test_df['id'].unique()]
label_test_last = test_df.groupby('id')['RUL'].nth(-1)[y_mask].values
label_test_last = label_test_last.reshape(label_test_last.shape[0],1).astype(np.float32)
print(label_test_last.shape)
print("label_test_last")
print(label_test_last)
# Out:
# seq_test_last
# (93, 50, 25)
# (93, 1)
# label_test_last
# [[ 69.]
#  [ 82.]
#  [ 91.]
#  [ 93.]
#  [ 91.]
#  [ 95.]
#  [111.]
#  [ 96.]
#  [ 97.]
#  [124.]
#  [ 95.]
#  [ 83.]
#  [ 84.]
#  [ 50.]
#  [ 28.]
#  [ 87.]
#  [ 16.]
#  [ 57.]
#  [113.]
#  [ 20.]
#  [119.]
#  [ 66.]
#  [ 97.]
#  [ 90.]
#  [115.]
#  [  8.]
#  [ 48.]
#  [106.]
#  [  7.]
#  [ 11.]
#  [ 19.]
#  [ 21.]
#  [ 50.]
#  [ 28.]
#  [ 18.]
#  [ 10.]
#  [ 59.]
#  [109.]
#  [114.]
#  [ 47.]
#  [135.]
#  [ 92.]
#  [ 21.]
#  [ 79.]
#  [114.]
#  [ 29.]
#  [ 26.]
#  [ 97.]
#  [137.]
#  [ 15.]
#  [103.]
#  [ 37.]
#  [114.]
#  [100.]
#  [ 21.]
#  [ 54.]
#  [ 72.]
#  [ 28.]
#  [128.]
#  [ 14.]
#  [ 77.]
#  [  8.]
#  [121.]
#  [ 94.]
#  [118.]
#  [ 50.]
#  [131.]
#  [126.]
#  [113.]
#  [ 10.]
#  [ 34.]
#  [107.]
#  [ 63.]
#  [ 90.]
#  [  8.]
#  [  9.]
#  [137.]
#  [ 58.]
#  [ 89.]
#  [116.]
#  [115.]
#  [136.]
#  [ 28.]
#  [ 38.]
#  [ 20.]
#  [ 85.]
#  [ 55.]
#  [128.]
#  [137.]
#  [ 82.]
#  [ 59.]
#  [117.]
#  [ 20.]]

# %% [markdown]
# # Modeling

# %%
import tensorflow.keras.backend as K

def r2_keras(y_true, y_pred):
    """Coefficient of Determination 
    """
    SS_res =  K.sum(K.square( y_true - y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# # LSTM Network
# # the network has a following layers:
# # 1. an LSTM layer with 100 units
# # 2. dropout after each LSTM layer to control overfitting
# # 3. an LSTM layer with 50 units
# # 4. dropout after each LSTM layer to control overfitting
# # 5. a dense output layer with single unit and linear activation since this is a regression problem

# %%
nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()

model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=100,
         return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
          units=50,
          return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=nb_out, activation='linear'))

model.compile(loss=tf.losses.MeanSquaredError(), optimizer=tf.keras.optimizers.RMSprop(), 
              metrics=[tf.metrics.MeanAbsoluteError(), r2_keras])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 100)           50400
#
#  dropout (Dropout)           (None, 50, 100)           0
#
#  lstm_1 (LSTM)               (None, 50)                30200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 80,651
# Trainable params: 80,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Paths

PATH_DATA = "./"
PATH_MODELS = PATH_DATA + "models/"
PATH_CHECKPOINTS = PATH_MODELS + "checkpoints/"
PATH_MODEL = PATH_CHECKPOINTS + "aircraft_regression_model.h5"

# stop training when validation acc starts dropping
# save checkpoint of model each period
now = datetime.now().strftime("%Y-%m-%d_%H%M")
# create callbacks
callbacks = [
    EarlyStopping(monitor="val_loss", min_delta=0, verbose=1, patience=10, mode='min'),
    ModelCheckpoint(
        ##PATH_CHECKPOINTS + now + "_Model_{epoch:02d}_{val_loss:.4f}.h5",
        PATH_MODEL,
        monitor="val_loss",
        save_best_only=True,
        verbose=1,
        mode='min'
    ),
]

# %%
# fit the network
# %time
history = model.fit(seq_array, label_array, epochs=100, batch_size=200, validation_split=0.05, verbose=2, shuffle=True,
          callbacks = callbacks
          )
# Out:
# Wall time: 0 ns
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 8144.33643, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 9s - loss: 8719.6914 - mean_absolute_error: 74.6171 - r2_keras: -1.6906e+00 - val_loss: 8144.3364 - val_mean_absolute_error: 71.7926 - val_r2_keras: -2.4209e+00 - 9s/epoch - 122ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 8144.33643 to 7620.46973, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 8056.9854 - mean_absolute_error: 70.7816 - r2_keras: -1.4858e+00 - val_loss: 7620.4697 - val_mean_absolute_error: 68.7512 - val_r2_keras: -2.1737e+00 - 1s/epoch - 18ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 7620.46973 to 7127.66260, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss:
ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 3492.25293 to 3375.51099, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3579.2605 - mean_absolute_error: 46.7740 - r2_keras: -9.8756e-02 - val_loss: 3375.5110 - val_mean_absolute_error: 45.8365 - val_r2_keras: -3.6436e-01 - 1s/epoch - 17ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 3375.51099 to 3289.13867, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3464.6292 - mean_absolute_error: 46.3163 - r2_keras: -6.4887e-02 - val_loss: 3289.1387 - val_mean_absolute_error: 45.5573 - val_r2_keras: -3.4860e-01 - 1s/epoch - 17ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 3289.13867 to 3227.94287, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3395.3262 - mean_absolute_error: 46.1249 - r2_keras: -4.2327e-02 - val_loss: 3227.9429 - val_mean_absolute_error: 45.4307 - val_r2_keras: -3.4515e-01 - 1s/epoch - 17ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 3227.94287 to 3189.97754, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3331.5757 - mean_absolute_error: 46.0208 - r2_keras: -2.3522e-02 - val_loss: 3189.9775 - val_mean_absolute_error: 45.4344 - val_r2_keras: -3.5226e-01 - 1s/epoch - 18ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 3189.97754 to 3174.24487, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3326.7229 - mean_absolute_error: 46.2341 - r2_keras: -2.1629e-02 - val_loss: 3174.2449 - val_mean_absolute_error: 45.5098 - val_r2_keras: -3.6345e-01 - 1s/epoch - 18ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 3174.24487 to 3089.06616, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 3293.6104 - mean_absolute_error: 46.0171 - r2_keras: -1.2867e-02 - val_loss: 3089.0662 - val_mean_absolute_error: 44.9718 - val_r2_keras: -3.3361e-01 - 1s/epoch - 17ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 3089.06616 to 2155.33252, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 2747.7837 - mean_absolute_error: 38.9026 - r2_keras: 0.1615 - val_loss: 2155.3325 - val_mean_absolute_error: 33.5634 - val_r2_keras: 0.1821 - 1s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 2155.33252 to 1870.76074, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 2141.7979 - mean_absolute_error: 31.4802 - r2_keras: 0.3446 - val_loss: 1870.7607 - val_mean_absolute_error: 29.9713 - val_r2_keras: 0.3140 - 1s/epoch - 17ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 1870.76074
# 75/75 - 1s - loss: 1914.7544 - mean_absolute_error: 28.9545 - r2_keras: 0.4145 - val_loss: 1937.5526 - val_mean_absolute_error: 32.4548 - val_r2_keras: 0.2013 - 1s/epoch - 17ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 1870.76074 to 1555.57861, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 1747.1210 - mean_absolute_error: 26.9740 - r2_keras: 0.4648 - val_loss: 1555.5786 - val_mean_absolute_error: 25.6845 - val_r2_keras: 0.4388 - 1s/epoch - 18ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 1555.57861 to 1380.99060, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 1626.0714 - mean_absolute_error: 25.8198 - r2_keras: 0.5031 - val_loss: 1380.9906 - val_mean_absolute_error: 22.1230 - val_r2_keras: 0.5342 - 1s/epoch - 17ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 1380.99060
# 75/75 - 1s - loss: 1503.2617 - mean_absolute_error: 24.5425 - r2_keras: 0.5404 - val_loss: 1563.4808 - val_mean_absolute_error: 29.0227 - val_r2_keras: 0.3453 - 1s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 1380.99060 to 1264.37109, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 1396.4301 - mean_absolute_error: 23.5670 - r2_keras: 0.5728 - val_loss: 1264.3711 - val_mean_absolute_error: 20.6954 - val_r2_keras: 0.5845 - 1s/epoch - 17ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 1264.37109
# 75/75 - 1s - loss: 1307.0715 - mean_absolute_error: 22.6515 - r2_keras: 0.6004 - val_loss: 1305.6552 - val_mean_absolute_error: 25.1137 - val_r2_keras: 0.4548 - 1s/epoch - 17ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 1264.37109 to 1052.18640, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 1232.4298 - mean_absolute_error: 21.8734 - r2_keras: 0.6262 - val_loss: 1052.1864 - val_mean_absolute_error: 20.6280 - val_r2_keras: 0.6351 - 1s/epoch - 18ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 1052.18640
# 75/75 - 1s - loss: 1164.0845 - mean_absolute_error: 21.3444 - r2_keras: 0.6449 - val_loss: 1130.6122 - val_mean_absolute_error: 22.0112 - val_r2_keras: 0.5457 - 1s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 1052.18640
# 75/75 - 1s - loss: 1094.7843 - mean_absolute_error: 20.6204 - r2_keras: 0.6664 - val_loss: 1108.4008 - val_mean_absolute_error: 22.2680 - val_r2_keras: 0.6122 - 1s/epoch - 17ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 1052.18640 to 933.98737, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 1032.7450 - mean_absolute_error: 20.0422 - r2_keras: 0.6851 - val_loss: 933.9874 - val_mean_absolute_error: 19.9078 - val_r2_keras: 0.6552 - 1s/epoch - 17ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 933.98737
# 75/75 - 1s - loss: 978.0157 - mean_absolute_error: 19.5048 - r2_keras: 0.7022 - val_loss: 1061.1005 - val_mean_absolute_error: 22.0983 - val_r2_keras: 0.5139 - 1s/epoch - 17ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 933.98737
# 75/75 - 1s - loss: 952.2623 - mean_absolute_error: 19.2642 - r2_keras: 0.7093 - val_loss: 1394.4119 - val_mean_absolute_error: 24.4377 - val_r2_keras: 0.5027 - 1s/epoch - 17ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 933.98737
# 75/75 - 1s - loss: 900.9715 - mean_absolute_error: 18.7654 - r2_keras: 0.7262 - val_loss: 1499.2645 - val_mean_absolute_error: 22.9459 - val_r2_keras: 0.5114 - 1s/epoch - 17ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 933.98737 to 922.39520, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 867.6601 - mean_absolute_error: 18.4601 - r2_keras: 0.7354 - val_loss: 922.3952 - val_mean_absolute_error: 19.2871 - val_r2_keras: 0.6569 - 1s/epoch - 17ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 922.39520
# 75/75 - 1s - loss: 832.9128 - mean_absolute_error: 18.0878 - r2_keras: 0.7464 - val_loss: 951.6474 - val_mean_absolute_error: 20.9157 - val_r2_keras: 0.5377 - 1s/epoch - 17ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 922.39520 to 844.74408, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 798.4164 - mean_absolute_error: 17.7917 - r2_keras: 0.7565 - val_loss: 844.7441 - val_mean_absolute_error: 20.1537 - val_r2_keras: 0.6648 - 1s/epoch - 17ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 844.74408 to 741.95227, saving model to ./models/checkpoints\aircraft_regression_model.h5
# 75/75 - 1s - loss: 785.1315 - mean_absolute_error: 17.7447 - r2_keras: 0.7603 - val_loss: 741.9523 - val_mean_absolute_error: 17.9442 - val_r2_keras: 0.6978 - 1s/epoch - 17ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 747.1458 - mean_absolute_error: 17.2591 - r2_keras: 0.7716 - val_loss: 940.4551 - val_mean_absolute_error: 19.9878 - val_r2_keras: 0.6313 - 1s/epoch - 17ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 727.3422 - mean_absolute_error: 17.1952 - r2_keras: 0.7785 - val_loss: 926.4288 - val_mean_absolute_error: 20.3108 - val_r2_keras: 0.6025 - 1s/epoch - 17ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 699.9081 - mean_absolute_error: 16.7584 - r2_keras: 0.7863 - val_loss: 1117.1848 - val_mean_absolute_error: 21.8717 - val_r2_keras: 0.5468 - 1s/epoch - 17ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 696.9698 - mean_absolute_error: 16.7725 - r2_keras: 0.7877 - val_loss: 1173.8783 - val_mean_absolute_error: 23.0186 - val_r2_keras: 0.4801 - 1s/epoch - 17ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 666.6102 - mean_absolute_error: 16.4416 - r2_keras: 0.7966 - val_loss: 1067.5509 - val_mean_absolute_error: 19.2790 - val_r2_keras: 0.6357 - 1s/epoch - 17ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 654.6421 - mean_absolute_error: 16.2615 - r2_keras: 0.7991 - val_loss: 991.9058 - val_mean_absolute_error: 21.0470 - val_r2_keras: 0.5833 - 1s/epoch - 17ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 636.3903 - mean_absolute_error: 16.1191 - r2_keras: 0.8057 - val_loss: 950.9654 - val_mean_absolute_error: 17.2121 - val_r2_keras: 0.6889 - 1s/epoch - 17ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 619.2269 - mean_absolute_error: 15.8446 - r2_keras: 0.8091 - val_loss: 1312.3323 - val_mean_absolute_error: 25.3338 - val_r2_keras: 0.4266 - 1s/epoch - 17ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 612.0007 - mean_absolute_error: 15.7785 - r2_keras: 0.8130 - val_loss: 1120.4880 - val_mean_absolute_error: 20.3648 - val_r2_keras: 0.4954 - 1s/epoch - 17ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 741.95227
# 75/75 - 1s - loss: 599.3175 - mean_absolute_error: 15.5594 - r2_keras: 0.8163 - val_loss: 883.8043 - val_mean_absolute_error: 19.6475 - val_r2_keras: 0.5212 - 1s/epoch - 17ms/step
# Epoch 50: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_absolute_error', 'r2_keras', 'val_loss', 'val_mean_absolute_error', 'val_r2_keras'])

# %%
# summarize history for R^2
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model r^2')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('\nMAE: {}'.format(scores[1]))
print('\nR^2: {}'.format(scores[2]))
# Out:
# 79/79 [==============================] - 1s 16ms/step - loss: 583.6794 - mean_absolute_error: 14.9082 - r2_keras: 0.7795
#
# MAE: 14.908193588256836
#
# R^2: 0.7795490622520447

# %%
y_pred = model.predict(seq_array,verbose=1, batch_size=200)
y_true = label_array
# Out:
# 79/79 [==============================] - 2s 11ms/step

# %%
# test metrics
model = load_model(PATH_MODEL, custom_objects={'r2_keras': r2_keras})
scores_test = model.evaluate(seq_test_last, label_test_last, verbose=2)
print('\nMAE: {}'.format(scores_test[1]))
print('\nR^2: {}'.format(scores_test[2]))
# Out:
# 3/3 - 1s - loss: 368.0554 - mean_absolute_error: 13.1524 - r2_keras: 0.7707 - 939ms/epoch - 313ms/step
#
# MAE: 13.1524019241333
#
# R^2: 0.7706791758537292

# %%
y_pred_test = model.predict(seq_test_last)
y_true_test = label_test_last
# Out:
# 3/3 [==============================] - 1s 33ms/step

# %%
# plot in blue color the predicted data and in green color the
# actual data to verify visually the accuracy of the model.

plt.plot(y_pred_test, color="blue")
plt.plot(y_true_test, color="green")
plt.title('prediction')
plt.ylabel('value')
plt.xlabel('row')
plt.legend(['predicted', 'actual data'], loc='upper left')
plt.show()
